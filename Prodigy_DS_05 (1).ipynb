# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:/Users/Acer/Downloads/archive (18)/US_Accidents_March23.csv")
data.head()
# Out:
#     ID   Source  Severity           Start_Time             End_Time  \
# 0  A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Roundabout  \
# 0  39.865147 -84.058723      NaN      NaN          0.01  ...      False
# 1  39.928059 -82.831184      NaN      NaN          0.01  ...      False
# 2  39.063148 -84.032608      NaN      NaN          0.01  ...      False
# 3  39.747753 -84.205582      NaN      NaN          0.01  ...      False
# 4  39.627781 -84.188354      NaN      NaN          0.01  ...      False
#
#   Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             object
#  4   End_Time               object
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature(F)         float64
# ...

# %%
data.shape
# Out:
# (7728394, 46)

# %%
data.drop(columns = ['ID','Description','County','Zipcode','Timezone','Airport_Code','Pressure(in)',
                     'Weather_Timestamp','Sunrise_Sunset','Wind_Chill(F)','Humidity(%)',
                     'Wind_Direction','Civil_Twilight','Nautical_Twilight','Astronomical_Twilight'], inplace=True)

# %%
data.head()
# Out:
#     Source  Severity           Start_Time             End_Time  Start_Lat  \
# 0  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00  39.865147
# 1  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59  39.928059
# 2  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27  39.063148
# 3  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34  39.747753
# 4  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07  39.627781
#
#    Start_Lng  End_Lat  End_Lng  Distance(mi)                     Street  ...  \
# 0 -84.058723      NaN      NaN          0.01                     I-70 E  ...
# 1 -82.831184      NaN      NaN          0.01                   Brice Rd  ...
# 2 -84.032608      NaN      NaN          0.01             State Route 32  ...
# 3 -84.205582      NaN      NaN          0.01                     I-75 S  ...
# 4 -84.188354      NaN      NaN          0.01  Miamisburg Centerville Rd  ...
#
# ...

# %%
data.isna().sum()
# Out:
# Source                     0
# Severity                   0
# Start_Time                 0
# End_Time                   0
# Start_Lat                  0
# Start_Lng                  0
# End_Lat              3402762
# End_Lng              3402762
# Distance(mi)               0
# Street                 10869
# City                     253
# State                      0
# Country                    0
# Temperature(F)        163853
# Visibility(mi)        177098
# Wind_Speed(mph)       571233
# Precipitation(in)    2203586
# Weather_Condition     173459
# Amenity                    0
# Bump                       0
# Crossing                   0
# Give_Way                   0
# Junction                   0
# No_Exit                    0
# Railway                    0
# Roundabout                 0
# Station                    0
# Stop                       0
# Traffic_Calming            0
# Traffic_Signal             0
# Turning_Loop               0
# dtype: int64

# %%
data.dropna(inplace = True)

# %%
data.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  3.615193e+06  3.615193e+06  3.615193e+06  3.615193e+06  3.615193e+06
# mean   2.079306e+00  3.613086e+01 -9.515621e+01  3.613106e+01 -9.515591e+01
# std    3.909192e-01  5.356258e+00  1.799212e+01  5.356454e+00  1.799181e+01
# min    1.000000e+00  2.456603e+01 -1.245481e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.318125e+01 -1.175465e+02  3.318071e+01 -1.175465e+02
# 50%    2.000000e+00  3.606116e+01 -8.727524e+01  3.606099e+01 -8.727539e+01
# 75%    2.000000e+00  4.014880e+01 -8.021020e+01  4.014908e+01 -8.020995e+01
# max    4.000000e+00  4.900058e+01 -6.748413e+01  4.907500e+01 -6.748413e+01
#
#        Distance(mi)  Temperature(F)  Visibility(mi)  Wind_Speed(mph)  \
# count  3.615193e+06    3.615193e+06    3.615193e+06     3.615193e+06
# mean   8.475917e-01    6.107687e+01    9.030884e+00     7.464283e+00
# std    1.826474e+00    1.934402e+01    2.595502e+00     5.589466e+00
# ...

# %% [markdown]
# # Top 10 Cities by Number of accidents

# %%
accidents_by_cities = data['City'].value_counts()
accidents_by_cities
# Out:
# City
# Miami                           143771
# Los Angeles                      80020
# Orlando                          75484
# Dallas                           50889
# Houston                          46882
#                                  ...
# David City                           1
# Odem                                 1
# Iredell                              1
# Shelbina                             1
# American Fork-Pleasant Grove         1
# Name: count, Length: 11314, dtype: int64

# %%
accidents_by_cities[:10]
# Out:
# City
# Miami          143771
# Los Angeles     80020
# Orlando         75484
# Dallas          50889
# Houston         46882
# Charlotte       40984
# San Diego       32855
# Raleigh         31656
# Nashville       28825
# Sacramento      28626
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(8,3))
accidents_by_cities[:10].plot(kind='bar', color='g')
ax.set(title = 'Top 10 cities By Number of Accidents',
       xlabel = 'Cities',
       ylabel = 'Accidents Count')
plt.show()

# %% [markdown]
# # Visual Distrubution of Survey

# %%
data['Severity'].value_counts()
# Out:
# Severity
# 2    3395964
# 4     118658
# 3      74980
# 1      25591
# Name: count, dtype: int64

# %%
sns.countplot(x='Severity', data=data)
plt.title('Distribution of Accident Severity')
plt.show()
# Out:
# C:\Users\Acer\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Acer\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Acer\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# # Accidents by Hotspots

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import seaborn as sns

# Create a new figure and set up the projection
plt.figure(figsize=(15, 10))
ax = plt.axes(projection=ccrs.PlateCarree())

# Add map features
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.LAND, edgecolor='black')
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.LAKES, alpha=0.5)
ax.add_feature(cfeature.RIVERS)

# Plot the scatter plot on the map
sns.scatterplot(x='Start_Lng', y='Start_Lat', data=data, alpha=0.1, ax=ax, transform=ccrs.PlateCarree())

# Set the title and labels
plt.title('Geographical Distribution of Accidents')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

# Show the plot
plt.show()
# Out:
# C:\Users\Acer\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Acer\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# # Visualize the weather Conditions and Accident severity

# %%
plt.figure(figsize=(7, 4))
sns.boxplot(x='Severity', y='Temperature(F)', data=data)
plt.title('Relationship between Temperature and Accident Severity')
plt.show()
# Out:
# C:\Users\Acer\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Acer\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Acer\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
f,ax=plt.subplots(2,3,figsize=(10,10))
ax[0,0] = data['Amenity'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0,0],colors=["red","orange"])
ax[0,0].set_title("Amenity",fontweight ="bold")

ax[0,1] = data['Crossing'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0,1],colors=["blue","salmon"])
ax[0,1].set_title("Crossing",fontweight ="bold")

ax[0,2] = data['Railway'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0,2],colors=["orange","yellow"])
ax[0,2].set_title("Railway",fontweight ="bold")

ax[1,0] = data['Station'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[1,0],colors=["cornflowerblue","salmon"])
ax[1,0].set_title("Station",fontweight ="bold")

ax[1,1] = data['Stop'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[1,1],colors=["blue","black"])
ax[1,1].set_title("Stop",fontweight ="bold")

ax[1,2] = data['Traffic_Signal'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[1,2],colors=["cornflowerblue","salmon"])
ax[1,2].set_title("Traffic_Signal",fontweight ="bold")
plt.show()
